# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import sys, gc, warnings, random, math, time, datetime, os
from tqdm import tqdm_notebook
warnings.filterwarnings('ignore')

from sklearn import metrics, preprocessing
from sklearn.model_selection import train_test_split, KFold, StratifiedKFold
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import roc_auc_score
from sklearn.decomposition import PCA
from sklearn.feature_selection import SelectFromModel, RFECV

import eli5
from eli5.sklearn import PermutationImportance

from catboost import CatBoostRegressor, CatBoostClassifier

from bayes_opt import BayesianOptimization

pd.set_option('display.max_columns', None)
# pd.set_option('display.max_rows', None)
# Out:
# Using TensorFlow backend.

# %%
# read df_train and df_test
df_train = pd.read_pickle("../features/df_train.pkl")
df_test = pd.read_pickle("../features/df_test.pkl")
TARGET = "hospital_death"

# read features cols and cat cols
all_features = np.load("../features/all_features.npy", allow_pickle=True).tolist()
categorical_features = np.load("../features/categorical_features.npy", allow_pickle=True).tolist()

# %%
print("train/test shape is:", df_train.shape, df_test.shape)
print("features used # is", len(all_features))
df_train[all_features].head()
# Out:
# train/test shape is: (91713, 186) (39308, 186)
# features used # is 149
#     age    bmi  ethnicity  gender  height  hospital_admit_source  \
# 0  68.0  22.73          2       1   180.3                      4
# 1  77.0  27.42          2       0   160.0                      4
# 2  25.0  31.95          2       0   172.7                      3
# 3  81.0  22.64          2       0   165.1                      8
# 4  19.0    NaN          2       1   188.0                     15
#
#    icu_admit_source  icu_type  pre_icu_los_days  weight  albumin_apache  \
# 0                 1         2          0.541667    73.9             2.3
# 1                 1         5          0.927778    70.2             NaN
# 2                 0         5          0.000694    95.3             NaN
# 3                 2         2          0.000694    61.7             NaN
# 4                 0         5          0.073611     NaN             NaN
#
#    apache_2_diagnosis  apache_3j_diagnosis  bilirubin_apache  bun_apache  \
# 0               113.0               502.01               0.4        31.0
# 1               108.0               203.01               NaN         9.0
# 2               122.0               703.03               NaN         NaN
# 3               203.0              1206.03               NaN         NaN
# 4               119.0               601.01               NaN         NaN
#
#    creatinine_apache  fio2_apache  gcs_eyes_apache  gcs_motor_apache  \
# 0               2.51          NaN              3.0               6.0
# 1               0.56          1.0              1.0               3.0
# 2                NaN          NaN              3.0               6.0
# 3                NaN          0.6              4.0               6.0
# 4                NaN          NaN              NaN               NaN
#
#    gcs_verbal_apache  glucose_apache  heart_rate_apache  hematocrit_apache  \
# 0                4.0           168.0              118.0               27.4
# 1                1.0           145.0              120.0               36.9
# 2                5.0             NaN              102.0                NaN
# 3                5.0           185.0              114.0               25.9
# 4                NaN             NaN               60.0                NaN
#
#    map_apache  paco2_apache  pao2_apache  ph_apache  resprate_apache  \
# 0        40.0           NaN          NaN        NaN             36.0
# 1        46.0          37.0         51.0       7.45             33.0
# 2        68.0           NaN          NaN        NaN             37.0
# 3        60.0          30.0        142.0       7.39              4.0
# 4       103.0           NaN          NaN        NaN             16.0
#
#    sodium_apache  temp_apache  urineoutput_apache  ventilated_apache  \
# 0          134.0         39.3                 NaN                0.0
# 1          145.0         35.1                 NaN                1.0
# 2            NaN         36.7                 NaN                0.0
# 3            NaN         34.8                 NaN                1.0
# 4            NaN         36.7                 NaN                0.0
#
#    wbc_apache  d1_diasbp_invasive_max  d1_diasbp_invasive_min  d1_diasbp_max  \
# 0        14.1                    46.0                    32.0           68.0
# 1        12.7                     NaN                     NaN           95.0
# 2         NaN                     NaN                     NaN           88.0
# 3         8.0                    62.0                    30.0           48.0
# 4         NaN                     NaN                     NaN           99.0
#
#    d1_diasbp_min  d1_diasbp_noninvasive_max  d1_diasbp_noninvasive_min  \
# 0           37.0                       68.0                       37.0
# 1           31.0                       95.0                       31.0
# 2           48.0                       88.0                       48.0
# 3           42.0                       48.0                       42.0
# 4           57.0                       99.0                       57.0
#
#    d1_heartrate_max  d1_heartrate_min  d1_mbp_invasive_max  \
# 0             119.0              72.0                 66.0
# 1             118.0              72.0                  NaN
# 2              96.0              68.0                  NaN
# 3             116.0              92.0                 92.0
# 4              89.0              60.0                  NaN
#
#    d1_mbp_invasive_min  d1_mbp_max  d1_mbp_min  d1_mbp_noninvasive_max  \
# 0                 40.0        89.0        46.0                    89.0
# 1                  NaN       120.0        38.0                   120.0
# 2                  NaN       102.0        68.0                   102.0
# 3                 52.0        84.0        84.0                    84.0
# 4                  NaN       104.0        90.0                   104.0
#
#    d1_mbp_noninvasive_min  d1_resprate_max  d1_resprate_min  d1_spo2_max  \
# 0                    46.0             34.0             10.0        100.0
# 1                    38.0             32.0             12.0        100.0
# 2                    68.0             21.0              8.0         98.0
# 3                    84.0             23.0              7.0        100.0
# 4                    90.0             18.0             16.0        100.0
#
#    d1_spo2_min  d1_sysbp_invasive_max  d1_sysbp_invasive_min  d1_sysbp_max  \
# 0         74.0                  122.0                   64.0         131.0
# 1         70.0                    NaN                    NaN         159.0
# 2         91.0                    NaN                    NaN         148.0
# 3         95.0                  164.0                   78.0         158.0
# 4         96.0                    NaN                    NaN         147.0
#
#    d1_sysbp_min  d1_sysbp_noninvasive_max  d1_sysbp_noninvasive_min  \
# 0          73.0                     131.0                      73.0
# 1          67.0                     159.0                      67.0
# 2         105.0                     148.0                     105.0
# 3          84.0                     158.0                      84.0
# 4         120.0                     147.0                     120.0
#
#    d1_temp_max  d1_temp_min  h1_diasbp_invasive_max  h1_diasbp_invasive_min  \
# 0         39.9         37.2                     NaN                     NaN
# 1         36.3         35.1                     NaN                     NaN
# 2         37.0         36.7                     NaN                     NaN
# 3         38.0         34.8                    62.0                    44.0
# 4         37.2         36.7                     NaN                     NaN
#
#    h1_diasbp_max  h1_diasbp_min  h1_diasbp_noninvasive_max  \
# 0           68.0           63.0                       68.0
# 1           61.0           48.0                       61.0
# 2           88.0           58.0                       88.0
# 3           62.0           44.0                        NaN
# 4           99.0           68.0                       99.0
#
#    h1_diasbp_noninvasive_min  h1_heartrate_max  h1_heartrate_min  \
# 0                       63.0             119.0             108.0
# 1                       48.0             114.0             100.0
# 2                       58.0              96.0              78.0
# 3                        NaN             100.0              96.0
# 4                       68.0              89.0              76.0
#
#    h1_mbp_invasive_min  h1_mbp_max  h1_mbp_min  h1_mbp_noninvasive_max  \
# 0                  NaN        86.0        85.0                    86.0
# 1                  NaN        85.0        57.0                    85.0
# 2                  NaN        91.0        83.0                    91.0
# 3                 71.0        92.0        71.0                     NaN
# 4                  NaN       104.0        92.0                   104.0
#
#    h1_mbp_noninvasive_min  h1_resprate_max  h1_resprate_min  h1_spo2_max  \
# 0                    85.0             26.0             18.0        100.0
# 1                    57.0             31.0             28.0         95.0
# 2                    83.0             20.0             16.0         98.0
# 3                     NaN             12.0             11.0        100.0
# 4                    92.0              NaN              NaN        100.0
#
#    h1_spo2_min  h1_sysbp_invasive_max  h1_sysbp_invasive_min  h1_sysbp_max  \
# 0         74.0                    NaN                    NaN         131.0
# 1         70.0                    NaN                    NaN          95.0
# 2         91.0                    NaN                    NaN         148.0
# 3         99.0                  136.0                  106.0         136.0
# 4        100.0                    NaN                    NaN         130.0
#
#    h1_sysbp_min  h1_sysbp_noninvasive_max  h1_sysbp_noninvasive_min  \
# 0         115.0                     131.0                     115.0
# 1          71.0                      95.0                      71.0
# 2         124.0                     148.0                     124.0
# 3         106.0                       NaN                       NaN
# 4         120.0                     130.0                     120.0
#
#    h1_temp_max  h1_temp_min  d1_albumin_max  d1_albumin_min  d1_bilirubin_max  \
# 0         39.5         37.5             2.3             2.3               0.4
# 1         36.3         36.3             1.6             1.6               0.5
# 2         36.7         36.7             NaN             NaN               NaN
# 3         35.6         34.8             NaN             NaN               NaN
# 4          NaN          NaN             NaN             NaN               NaN
#
#    d1_bilirubin_min  d1_bun_max  d1_bun_min  d1_calcium_max  d1_calcium_min  \
# 0               0.4        31.0        30.0             8.5             7.4
# 1               0.5        11.0         9.0             8.6             8.0
# 2               NaN         NaN         NaN             NaN             NaN
# 3               NaN         NaN         NaN             NaN             NaN
# 4               NaN         NaN         NaN             NaN             NaN
#
#    d1_creatinine_max  d1_creatinine_min  d1_glucose_max  d1_glucose_min  \
# 0               2.51               2.23           168.0           109.0
# 1               0.71               0.56           145.0           128.0
# 2                NaN                NaN             NaN             NaN
# 3                NaN                NaN           185.0            88.0
# 4                NaN                NaN             NaN             NaN
#
#    d1_hco3_max  d1_hco3_min  d1_hemaglobin_max  d1_hemaglobin_min  \
# 0         19.0         15.0                8.9                8.9
# 1         27.0         26.0               11.3               11.1
# 2          NaN          NaN                NaN                NaN
# 3          NaN          NaN               11.6                8.9
# 4          NaN          NaN                NaN                NaN
#
#    d1_hematocrit_max  d1_hematocrit_min  d1_inr_max  d1_inr_min  \
# 0               27.4               27.4         NaN         NaN
# 1               36.9               36.1         1.3         1.3
# 2                NaN                NaN         NaN         NaN
# 3               34.0               25.9         1.6         1.1
# 4                NaN                NaN         NaN         NaN
#
#    d1_lactate_max  d1_lactate_min  d1_platelets_max  d1_platelets_min  \
# 0             1.3             1.0             233.0             233.0
# 1             3.5             3.5             557.0             487.0
# 2             NaN             NaN               NaN               NaN
# 3             NaN             NaN             198.0              43.0
# 4             NaN             NaN               NaN               NaN
#
#    d1_potassium_max  d1_potassium_min  d1_sodium_max  d1_sodium_min  \
# 0               4.0               3.4          136.0          134.0
# 1               4.2               3.8          145.0          145.0
# 2               NaN               NaN            NaN            NaN
# 3               5.0               3.5            NaN            NaN
# 4               NaN               NaN            NaN            NaN
#
#    d1_wbc_max  d1_wbc_min  h1_bun_max  h1_calcium_max  h1_creatinine_max  \
# 0        14.1        14.1         NaN             NaN                NaN
# 1        23.3        12.7         9.0             8.6               0.56
# 2         NaN         NaN         NaN             NaN                NaN
# 3         9.0         8.0         NaN             NaN                NaN
# 4         NaN         NaN         NaN             NaN                NaN
#
#    h1_glucose_max  h1_glucose_min  h1_hco3_max  h1_hemaglobin_max  \
# 0             NaN             NaN          NaN                NaN
# 1           145.0           143.0         27.0               11.3
# 2             NaN             NaN          NaN                NaN
# 3             NaN             NaN          NaN               11.6
# 4             NaN             NaN          NaN                NaN
#
#    h1_hemaglobin_min  h1_hematocrit_max  h1_hematocrit_min  h1_lactate_max  \
# 0                NaN                NaN                NaN             NaN
# 1               11.3               36.9               36.9             3.5
# 2                NaN                NaN                NaN             NaN
# 3               11.6               34.0               34.0             NaN
# 4                NaN                NaN                NaN             NaN
#
#    h1_platelets_max  h1_potassium_max  h1_wbc_max  d1_arterial_pco2_max  \
# 0               NaN               NaN         NaN                   NaN
# 1             557.0               4.2        12.7                  37.0
# 2               NaN               NaN         NaN                   NaN
# 3              43.0               NaN         8.8                  37.0
# 4               NaN               NaN         NaN                   NaN
#
#    d1_arterial_pco2_min  d1_arterial_ph_max  d1_arterial_ph_min  \
# 0                   NaN                 NaN                 NaN
# 1                  37.0                7.45                7.45
# 2                   NaN                 NaN                 NaN
# 3                  27.0                7.44                7.34
# 4                   NaN                 NaN                 NaN
#
#    d1_arterial_po2_max  d1_arterial_po2_min  d1_pao2fio2ratio_max  \
# 0                  NaN                  NaN                   NaN
# 1                 51.0                 51.0                  54.8
# 2                  NaN                  NaN                   NaN
# 3                337.0                102.0                 342.5
# 4                  NaN                  NaN                   NaN
#
#    d1_pao2fio2ratio_min  h1_arterial_pco2_max  h1_arterial_pco2_min  \
# 0                   NaN                   NaN                   NaN
# 1             51.000000                  37.0                  37.0
# 2                   NaN                   NaN                   NaN
# 3            236.666667                  36.0                  33.0
# 4                   NaN                   NaN                   NaN
#
#    h1_arterial_ph_max  h1_arterial_ph_min  h1_arterial_po2_max  \
# 0                 NaN                 NaN                  NaN
# 1                7.45                7.45                 51.0
# 2                 NaN                 NaN                  NaN
# 3                7.37                7.34                337.0
# 4                 NaN                 NaN                  NaN
#
#    h1_arterial_po2_min  h1_pao2fio2ratio_max  apache_4a_hospital_death_prob  \
# 0                  NaN                   NaN                           0.10
# 1                 51.0                  51.0                           0.47
# 2                  NaN                   NaN                           0.00
# 3                265.0                 337.0                           0.04
# 4                  NaN                   NaN                            NaN
#
#    apache_4a_icu_death_prob  diabetes_mellitus  solid_tumor_with_metastasis  \
# 0                      0.05                1.0                          0.0
# 1                      0.29                1.0                          0.0
# 2                      0.00                0.0                          0.0
# 3                      0.03                0.0                          0.0
# 4                       NaN                0.0                          0.0
#
#    apache_3j_bodysystem  apache_2_bodysystem
# 0                     9                    0
# 1                     8                    6
# 2                     5                    3
# 3                     0                    0
# 4                    10                    7

# %%
param = {
    'eval_metric': 'AUC',
    'loss_function': 'Logloss',
    'learning_rate': 0.01,
    'n_estimators': 5000,
    'l2_leaf_reg': 6,
    "subsample": 0.6,
    "rsm": 0.2,
    "max_depth": 8,
    'random_seed': 42,
#     'task_type':'GPU',
}

# %%
cv= 5
kf = StratifiedKFold(n_splits=cv, shuffle=True, random_state=42)

oof_pred = np.zeros(df_train.shape[0])
y_pred = np.zeros(df_test.shape[0])
df_test[TARGET] = 0

for fold, (train_index, valid_index) in enumerate(kf.split(df_train, y = df_train[TARGET])):
    
    print("Traning on folder", fold, "...")
    X_train, X_valid = df_train.iloc[train_index][all_features], df_train.iloc[valid_index][all_features]
    y_train, y_valid = df_train.iloc[train_index][TARGET], df_train.iloc[valid_index][TARGET]
    
    model_lgb = CatBoostClassifier(**param)
    
    model_lgb.fit(X_train, y_train,
                    eval_set=[(X_train, y_train), (X_valid, y_valid)],
                    cat_features=categorical_features,
                    early_stopping_rounds=500,
                    verbose=1000)
    y_pred_valid = model_lgb.predict(X_valid,prediction_type='Probability')[:,1]
    oof_pred[valid_index] = y_pred_valid
    
    df_test[TARGET] += model_lgb.predict(df_test[all_features],prediction_type='Probability')[:,1] / cv
    print("")
    
print("-------------------------------------")
print("Overall AUC score is", roc_auc_score(df_train[TARGET], oof_pred))
# Out:
# Traning on folder 0 ...
# 0:	test: 0.7961512	test1: 0.7946858	best: 0.7946858 (0)	total: 80.5ms	remaining: 6m 42s
# 1000:	test: 0.9212505	test1: 0.8992091	best: 0.8992091 (1000)	total: 29.4s	remaining: 1m 57s
# 2000:	test: 0.9415630	test1: 0.9029193	best: 0.9029193 (2000)	total: 57.6s	remaining: 1m 26s
# 3000:	test: 0.9556467	test1: 0.9044300	best: 0.9044510 (2992)	total: 1m 25s	remaining: 57.3s
# 4000:	test: 0.9659903	test1: 0.9052302	best: 0.9052889 (3887)	total: 1m 56s	remaining: 29.2s
# 4999:	test: 0.9740244	test1: 0.9056552	best: 0.9057546 (4850)	total: 2m 25s	remaining: 0us
#
# bestTest = 0.9057546093
# bestIteration = 4850
#
# Shrink model to first 4851 iterations.
#
# Traning on folder 1 ...
# 0:	test: 0.7800431	test1: 0.7870187	best: 0.7870187 (0)	total: 26.4ms	remaining: 2m 11s
# 1000:	test: 0.9218189	test1: 0.8992904	best: 0.8992904 (1000)	total: 28.2s	remaining: 1m 52s
# 2000:	test: 0.9417422	test1: 0.9030040	best: 0.9030041 (1999)	total: 57s	remaining: 1m 25s
# 3000:	test: 0.9552285	test1: 0.9046735	best: 0.9046740 (2999)	total: 1m 26s	remaining: 57.9s
# 4000:	test: 0.9657648	test1: 0.9052729	best: 0.9053134 (3949)	total: 1m 56s	remaining: 29.2s
# 4999:	test: 0.9739881	test1: 0.9055271	best: 0.9055279 (4998)	total: 2m 25s	remaining: 0us
#
# bestTest = 0.9055278941
# bestIteration = 4998
#
# Shrink model to first 4999 iterations.
#
# Traning on folder 2 ...
# 0:	test: 0.7836082	test1: 0.7714747	best: 0.7714747 (0)	total: 28ms	remaining: 2m 20s
# 1000:	test: 0.9231289	test1: 0.8949488	best: 0.8949488 (1000)	total: 28.1s	remaining: 1m 52s
# 2000:	test: 0.9437727	test1: 0.8985308	best: 0.8985308 (2000)	total: 56.2s	remaining: 1m 24s
# 3000:	test: 0.9577434	test1: 0.9000864	best: 0.9001367 (2948)	total: 1m 26s	remaining: 57.9s
# 4000:	test: 0.9678638	test1: 0.9011004	best: 0.9011007 (3999)	total: 1m 56s	remaining: 29.1s
# 4999:	test: 0.9758077	test1: 0.9012926	best: 0.9013294 (4592)	total: 2m 25s	remaining: 0us
#
# bestTest = 0.9013294219
# bestIteration = 4592
#
# Shrink model to first 4593 iterations.
#
# Traning on folder 3 ...
# 0:	test: 0.7820974	test1: 0.7706068	best: 0.7706068 (0)	total: 27.5ms	remaining: 2m 17s
# 1000:	test: 0.9217291	test1: 0.8995575	best: 0.8995575 (1000)	total: 28.7s	remaining: 1m 54s
# 2000:	test: 0.9426068	test1: 0.9037048	best: 0.9037048 (2000)	total: 59.1s	remaining: 1m 28s
# 3000:	test: 0.9567088	test1: 0.9052661	best: 0.9052717 (2998)	total: 1m 28s	remaining: 58.7s
# 4000:	test: 0.9672033	test1: 0.9059997	best: 0.9060515 (3976)	total: 1m 59s	remaining: 29.7s
# 4999:	test: 0.9754352	test1: 0.9063572	best: 0.9063878 (4938)	total: 2m 27s	remaining: 0us
#
# bestTest = 0.9063877841
# bestIteration = 4938
#
# Shrink model to first 4939 iterations.
#
# Traning on folder 4 ...
# 0:	test: 0.7860518	test1: 0.7782521	best: 0.7782521 (0)	total: 27.9ms	remaining: 2m 19s
# 1000:	test: 0.9213967	test1: 0.9014034	best: 0.9014034 (1000)	total: 27.1s	remaining: 1m 48s
# 2000:	test: 0.9416551	test1: 0.9054829	best: 0.9054829 (2000)	total: 57.4s	remaining: 1m 26s
# 3000:	test: 0.9557065	test1: 0.9070659	best: 0.9070699 (2998)	total: 1m 25s	remaining: 57.3s
# 4000:	test: 0.9664564	test1: 0.9077123	best: 0.9077175 (3976)	total: 1m 53s	remaining: 28.3s
# 4999:	test: 0.9746368	test1: 0.9079851	best: 0.9080046 (4841)	total: 2m 21s	remaining: 0us
#
# bestTest = 0.9080045506
# bestIteration = 4841
#
# Shrink model to first 4842 iterations.
#
# -------------------------------------
# Overall AUC score is 0.9053617777745078

# %%
# 0.90
WRITE_TOKEN = False
# submission should be (39308, 2)
print("submission shape is", df_test[["encounter_id", TARGET]].shape)
if WRITE_TOKEN:
    df_test[["encounter_id", TARGET]].to_csv("../submissions/sub-cat.csv", index=None)
    print("submission is saved successfully!")
# Out:
# submission shape is (39308, 2)
# submission is saved successfully!
